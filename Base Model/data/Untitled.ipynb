# %%
import sys
sys.path.insert(0, '/home/compute.ashesi.lan/e.bilson/V2/Solar_V2')

from reorganize_dataset import DatasetReorganizer

# Use the V2 data location
reorganizer = DatasetReorganizer(
    source_data='/home/compute.ashesi.lan/e.bilson/V2/data/images',
    target_data='/home/compute.ashesi.lan/e.bilson/V2/data_v2/images'
)

reorganizer.run()
# Out:
# ...
# DATASET REORGANIZATION - v2.0
# ...
#
# Source: /home/compute.ashesi.lan/e.bilson/V2/data/images
# Target: /home/compute.ashesi.lan/e.bilson/V2/data_v2/images
#
# 📁 Creating new directory structure...
# ✅ Directory structure created!
#
# 🔄 Reorganizing train split...
#    Cell                 → Cell-Fault          :  1501 images
#    Cell-Multi           → Cell-Fault          :  1030 images
#    Cracking             → Cracking            :   752 images
#    Diode                → Diode-Fault         :  1199 images
#    Diode-Multi          → Diode-Fault         :   140 images
#    Hot-Spot             → Hot-Spot            :   199 images
#    Hot-Spot-Multi       → Hot-Spot            :   196 images
#    No-Anomaly           → No-Anomaly          :  8000 images
#    Offline-Module       → Offline-Module      :   661 images
#    Shadowing            → Shadowing           :   844 images
#    Soiling              → Soiling             :   163 images
# ...

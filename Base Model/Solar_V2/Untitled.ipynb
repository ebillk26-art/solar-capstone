# %%
exec(open('train_yolov8_v2.py').read())
# Out:
# 🎮 GPU: Quadro RTX 6000 (25.2GB)
# ...
# YOLOV8 TRAINING - v2.0
# ...
# Model: yolov8l-cls
# Data: ../data_v2/images
# Classes: 9
# Image Size: 640px
# Epochs: 200
# ...
#
# 📊 Analyzing Dataset...
#
# Class                          |    Train |      Val |    Total
# ----------------------------------------------------------------------
# Cell-Fault                     |    2,531 |      315 |    2,846
# Cracking                       |      752 |       94 |      846
# Diode-Fault                    |    1,339 |      166 |    1,505
# Hot-Spot                       |      395 |       48 |      443
# No-Anomaly                     |    8,000 |    1,000 |    9,000
# Offline-Module                 |      661 |       82 |      743
# Shadowing                      |      844 |      105 |      949
# Soiling                        |      163 |       20 |      183
# Vegetation                     |    1,311 |      163 |    1,474
# ----------------------------------------------------------------------
# ...
